# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
from pathlib import Path
import math
import scienceplots
import latex
from utils import plot_quad_plot

# %%
plot_quad_plot('GA', [50, 30, 20], '../random_init/', [3, 5, 10, 13], 'a')

# %%
plot_quad_plot('GA', [40, 40, 20], '../random_init/', [3, 5, 10, 13], 'b')

# %%
plot_quad_plot('GA', [30, 40, 30], '../random_init/', [3, 5, 10, 13], 'c')

# %%
plot_quad_plot('GA', [20, 50, 30], '../random_init/', [3, 5, 10, 13], 'd')

# %%
plot_quad_plot('GA', [10, 50, 40], '../random_init/', [3, 5, 10, 13], 'e')
